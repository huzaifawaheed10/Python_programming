# %% [markdown]
# ### HELLO WORLD

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### VARIABLE

# %%
movies=[]
a=input("enter first movie:")
b=input("enter second movie:")
c=input("enter third movie:")
movies.append(a)
movies.append(b)
movies.append(c)
print(movies)
# Out:
# ['saiyaara \n', 'pk\n', 'fast and furious']
